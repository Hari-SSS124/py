# %%
a = 10
a
# Out:
# Running cells with 'myenv (Python 3.12.4)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/mahes/OneDrive/Desktop/New folder (4)/myenv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
